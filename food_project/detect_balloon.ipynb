# %% [markdown]
# # Object Detection using Tensorflow Object Detection API
#
# In this lab exercise, we will use our trained custom object detection model to detect balloons in both images and videos.

# %% [markdown]
# ## Imports and Setup
#
# Let's start with the base imports.

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\anaconda3\lib\site-packages (from opencv-python) (1.21.6)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72

# %%
# !pip install tensorflow-object-detection
# Out:
# Collecting tensorflow-object-detection
#   Using cached tensorflow_object_detection-0.0.6-py3-none-any.whl
# Requirement already satisfied: contextlib2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-object-detection) (21.6.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-object-detection) (65.6.3)
# Collecting pycocotools-fix
#   Using cached pycocotools-fix-2.0.0.9.tar.gz (124 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: lxml in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-object-detection) (4.9.1)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-object-detection) (9.3.0)
# Requirement already satisfied: jupyter in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-object-detection) (1.0.0)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-object-detection) (3.7.0)
# Requirement already satisfied: cython in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-object-detection) (0.29.35)
# Requirement already satisfied: notebook in c:\users\hp\anaconda3\lib\site-packages (from jupyter->tensorflow-object-detection) (6.5.2)
# Requirement already satisfied: nbconvert in c:\users\hp\anaconda3\lib\site-packages (from jupyter->tensorflow-object-detection) (6.5.4)
# Requirement already satisfied: qtconsole in c:\users\hp\anaconda3\lib\site-packages (from jupyter->tensorflow-object-detection) (5.4.0)
# Requirement already satisfied: ipykernel in c:\users\hp\anaconda3\lib\site-packages (from jupyter->tensorflow-object-detection) (6.19.2)
# Requirement already satisfied: ipywidgets in c:\users\hp\anaconda3\lib\site-packages (from jupyter->tensorflow-object-detection) (7.6.5)
# Requirement already satisfied: jupyter-console in c:\users\hp\anaconda3\lib\site-packages (from jupyter->tensorflow-object-detection) (6.6.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (1.0.5)
# Requirement already satisfied: numpy>=1.20 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (1.21.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->tensorflow-object-detection) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->tensorflow-object-detection) (1.16.0)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (5.9.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (23.2.0)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (5.7.1)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (0.1.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (8.10.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection) (6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection) (5.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection) (0.2.0)
# Requirement already satisfied: pygments in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->tensorflow-object-detection) (2.11.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->tensorflow-object-detection) (3.0.36)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->tensorflow-object-detection) (5.2.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (0.8.4)
# Requirement already satisfied: tinycss2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (1.2.1)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (2.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (3.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection) (4.11.1)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->tensorflow-object-detection) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->tensorflow-object-detection) (0.5.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->tensorflow-object-detection) (0.17.1)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->tensorflow-object-detection) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->tensorflow-object-detection) (1.8.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\hp\anaconda3\lib\site-packages (from qtconsole->jupyter->tensorflow-object-detection) (2.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.18.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.4.6)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (5.1.1)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->tensorflow-object-detection) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->tensorflow-object-detection) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->tensorflow-object-detection) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->tensorflow-object-detection) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->tensorflow-object-detection) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->tensorflow-object-detection) (3.2.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->tensorflow-object-detection) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->tensorflow-object-detection) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->tensorflow-object-detection) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->tensorflow-object-detection) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->tensorflow-object-detection) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.8.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->tensorflow-object-detection) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->tensorflow-object-detection) (22.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->tensorflow-object-detection) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->tensorflow-object-detection) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->tensorflow-object-detection) (1.15.1)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (2.0.5)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->tensorflow-object-detection) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->tensorflow-object-detection) (3.4)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->tensorflow-object-detection) (2.21)
# Building wheels for collected packages: pycocotools-fix
#   Building wheel for pycocotools-fix (setup.py): started
#   Building wheel for pycocotools-fix (setup.py): finished with status 'error'
#   Running setup.py clean for pycocotools-fix
# Failed to build pycocotools-fix
# Installing collected packages: pycocotools-fix, tensorflow-object-detection
#   Running setup.py install for pycocotools-fix: started
#   Running setup.py install for pycocotools-fix: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\coco.py -> build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\cocoeval.py -> build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\mask.py -> build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\__init__.py -> build\lib.win-amd64-cpython-310\pycocotools
#   running build_ext
#   skipping 'pycocotools\_mask.c' Cython extension (up-to-date)
#   building 'pycocotools._mask' extension
#   creating build\temp.win-amd64-cpython-310
#   creating build\temp.win-amd64-cpython-310\Release
#   creating build\temp.win-amd64-cpython-310\Release\common
#   creating build\temp.win-amd64-cpython-310\Release\pycocotools
#   "C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\Users\HP\anaconda3\lib\site-packages\numpy\core\include -I./common -IC:\Users\HP\anaconda3\include -IC:\Users\HP\anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt" /Tc./common/maskApi.c /Fobuild\temp.win-amd64-cpython-310\Release\./common/maskApi.obj -Wno-cpp -Wno-unused-function -std=c99
#   cl : Command line error D8021 : invalid numeric argument '/Wno-cpp'
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.29.30133\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pycocotools-fix
#   error: subprocess-exited-with-error
#
#   Running setup.py install for pycocotools-fix did not run successfully.
#   exit code: 1
#
#   [22 lines of output]
#   running install
#   C:\Users\HP\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\coco.py -> build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\cocoeval.py -> build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\mask.py -> build\lib.win-amd64-cpython-310\pycocotools
#   copying pycocotools\__init__.py -> build\lib.win-amd64-cpython-310\pycocotools
#   running build_ext
#   skipping 'pycocotools\_mask.c' Cython extension (up-to-date)
#   building 'pycocotools._mask' extension
#   creating build\temp.win-amd64-cpython-310
#   creating build\temp.win-amd64-cpython-310\Release
#   creating build\temp.win-amd64-cpython-310\Release\common
#   creating build\temp.win-amd64-cpython-310\Release\pycocotools
#   "C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\Users\HP\anaconda3\lib\site-packages\numpy\core\include -I./common -IC:\Users\HP\anaconda3\include -IC:\Users\HP\anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt" /Tc./common/maskApi.c /Fobuild\temp.win-amd64-cpython-310\Release\./common/maskApi.obj -Wno-cpp -Wno-unused-function -std=c99
#   cl : Command line error D8021 : invalid numeric argument '/Wno-cpp'
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.29.30133\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# pycocotools-fix
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
# !pip list
# Out:
# Package                        Version
# ------------------------------ ---------------
# absl-py                        1.3.0
# aiohttp                        3.8.3
# aiosignal                      1.2.0
# alabaster                      0.7.12
# anaconda-client                1.11.1
# anaconda-navigator             2.4.1
# anaconda-project               0.11.1
# anyio                          3.5.0
# appdirs                        1.4.4
# argon2-cffi                    21.3.0
# argon2-cffi-bindings           21.2.0
# arrow                          1.2.3
# asgiref                        3.7.2
# astroid                        2.14.2
# astropy                        5.1
# asttokens                      2.0.5
# astunparse                     1.6.3
# async-generator                1.10
# async-timeout                  4.0.2
# atomicwrites                   1.4.0
# attr                           0.3.1
# attrs                          22.1.0
# Automat                        20.2.0
# autopep8                       1.6.0
# azure-core                     1.27.0
# azure-storage-blob             12.16.0
# Babel                          2.11.0
# backcall                       0.2.0
# backports.functools-lru-cache  1.6.4
# backports.tempfile             1.0
# backports.weakref              1.0.post1
# bcrypt                         3.2.0
# beautifulsoup4                 4.11.1
# binaryornot                    0.4.4
# black                          22.6.0
# bleach                         5.0.1
# blinker                        1.4
# bokeh                          2.4.3
# boltons                        23.0.0
# boto                           2.49.0
# boto3                          1.16.63
# botocore                       1.19.63
# Bottleneck                     1.3.5
# boxing                         0.1.4
# brotlipy                       0.7.0
# bs4                            0.0.1
# cachetools                     4.2.2
# certifi                        2023.5.7
# cffi                           1.15.1
# chardet                        4.0.0
# charset-normalizer             2.0.4
# click                          8.0.4
# cloudpickle                    2.0.0
# clyent                         1.2.2
# colorama                       0.4.6
# colorcet                       3.0.1
# comm                           0.1.2
# conda                          23.3.1
# conda-build                    3.23.3
# conda-content-trust            0.1.3
# conda-pack                     0.6.0
# conda-package-handling         2.0.2
# conda_package_streaming        0.7.0
# conda-repo-cli                 1.0.27
# conda-token                    0.4.0
# conda-verify                   3.4.2
# constantly                     15.1.0
# contextlib2                    21.6.0
# contourpy                      1.0.5
# cookiecutter                   1.7.3
# coreapi                        2.3.3
# coreschema                     0.0.4
# cryptography                   39.0.1
# cssselect                      1.1.0
# cycler                         0.11.0
# Cython                         0.29.35
# cytoolz                        0.12.0
# daal4py                        2023.0.2
# dask                           2022.7.0
# datashader                     0.14.4
# datashape                      0.5.4
# debugpy                        1.5.1
# decorator                      5.1.1
# defusedxml                     0.7.1
# diff-match-patch               20200713
# dill                           0.3.6
# distributed                    2022.7.0
# Django                         3.2.16
# django-annoying                0.10.6
# django-cors-headers            3.6.0
# django-debug-toolbar           3.2.1
# django-extensions              3.1.0
# django-filter                  2.4.0
# django-model-utils             4.1.1
# django-ranged-fileresponse     0.1.2
# django-rest-swagger            2.2.0
# django-rq                      2.5.1
# django-storages                1.12.3
# django-user-agents             0.4.0
# djangorestframework            3.13.1
# docstring-to-markdown          0.11
# docutils                       0.18.1
# drf-dynamic-fields             0.3.0
# drf-flex-fields                0.9.5
# drf-generators                 0.3.0
# drf-yasg                       1.20.0
# entrypoints                    0.4
# et-xmlfile                     1.1.0
# exceptiongroup                 1.1.1
# executing                      0.8.3
# expiringdict                   1.2.2
# fastjsonschema                 2.16.2
# filelock                       3.9.0
# flake8                         6.0.0
# Flask                          2.2.2
# flatbuffers                    2.0
# flit_core                      3.6.0
# fonttools                      4.25.0
# frozenlist                     1.3.3
# fsspec                         2022.11.0
# future                         0.18.3
# gast                           0.4.0
# gensim                         4.3.0
# glob2                          0.7
# google-api-core                2.10.0
# google-auth                    2.11.0
# google-auth-oauthlib           0.4.4
# google-cloud-appengine-logging 1.1.0
# google-cloud-audit-log         0.2.0
# google-cloud-core              2.3.2
# google-cloud-logging           2.7.2
# google-cloud-storage           2.5.0
# google-crc32c                  1.5.0
# google-pasta                   0.2.0
# google-resumable-media         2.3.3
# googleapis-common-protos       1.56.4
# greenlet                       2.0.1
# grpc-google-iam-v1             0.12.3
# grpcio                         1.48.2
# grpcio-status                  1.48.2
# h11                            0.14.0
# h5py                           3.7.0
# HeapDict                       1.0.1
# holoviews                      1.15.4
# htmlmin                        0.1.12
# huggingface-hub                0.10.1
# hvplot                         0.8.2
# hyperlink                      21.0.0
# idna                           3.4
# imagecodecs                    2021.8.26
# imageio                        2.26.0
# imagesize                      1.4.1
# imbalanced-learn               0.10.1
# importlib-metadata             4.11.3
# importlib-resources            5.12.0
# incremental                    21.3.0
# inflection                     0.5.1
# iniconfig                      1.1.1
# intake                         0.6.7
# intervaltree                   3.1.0
# ipykernel                      6.19.2
# ipython                        8.10.0
# ipython-genutils               0.2.0
# ipywidgets                     7.6.5
# isodate                        0.6.1
# isort                          5.9.3
# itemadapter                    0.3.0
# itemloaders                    1.0.4
# itsdangerous                   2.0.1
# itypes                         1.2.0
# jedi                           0.18.1
# jellyfish                      0.9.0
# Jinja2                         3.1.2
# jinja2-time                    0.2.0
# jmespath                       0.10.0
# joblib                         1.1.1
# json5                          0.9.6
# jsonpatch                      1.32
# jsonpointer                    2.1
# jsonschema                     3.2.0
# jupyter                        1.0.0
# jupyter_client                 7.3.4
# jupyter-console                6.6.2
# jupyter_core                   5.2.0
# jupyter-server                 1.23.4
# jupyterlab                     3.5.3
# jupyterlab-pygments            0.1.2
# jupyterlab_server              2.19.0
# jupyterlab-widgets             1.0.0
# keras                          2.10.0
# Keras-Preprocessing            1.1.2
# keyring                        23.4.0
# kiwisolver                     1.4.4
# label-studio                   1.7.3
# label-studio-converter         0.0.51
# label-studio-tools             0.0.2
# launchdarkly-server-sdk        7.5.0
# lazy-object-proxy              1.6.0
# libarchive-c                   2.9
# libclang                       16.0.0
# llvmlite                       0.39.1
# locket                         1.0.0
# lockfile                       0.12.2
# lxml                           4.9.1
# lz4                            3.1.3
# Markdown                       3.4.1
# MarkupSafe                     2.1.1
# matplotlib                     3.7.0
# matplotlib-inline              0.1.6
# mccabe                         0.7.0
# menuinst                       1.4.19
# mistune                        0.8.4
# mkl-fft                        1.3.1
# mkl-random                     1.2.2
# mkl-service                    2.4.0
# mock                           4.0.3
# mpmath                         1.2.1
# msgpack                        1.0.3
# multidict                      6.0.2
# multipledispatch               0.6.0
# munkres                        1.1.4
# mypy-extensions                0.4.3
# mysql-connector-python         8.0.33
# navigator-updater              0.3.0
# nbclassic                      0.5.2
# nbclient                       0.5.13
# nbconvert                      6.5.4
# nbformat                       5.7.0
# nest-asyncio                   1.5.6
# networkx                       2.8.4
# nltk                           3.6.7
# notebook                       6.5.2
# notebook_shim                  0.2.2
# numba                          0.56.4
# numexpr                        2.8.4
# numpy                          1.21.6
# numpydoc                       1.5.0
# oauthlib                       3.2.2
# object-detection               0.0.3
# openapi-codec                  1.3.2
# opencv-python                  4.7.0.72
# openpyxl                       3.0.10
# opt-einsum                     3.3.0
# ordered-set                    4.0.2
# outcome                        1.2.0
# packaging                      22.0
# pandas                         1.3.5
# pandocfilters                  1.5.0
# panel                          0.14.3
# param                          1.12.3
# paramiko                       2.8.1
# parsel                         1.6.0
# parso                          0.8.3
# partd                          1.2.0
# pathlib                        1.0.1
# pathspec                       0.10.3
# patsy                          0.5.3
# pep8                           1.7.1
# pexpect                        4.8.0
# pickleshare                    0.7.5
# Pillow                         9.3.0
# pip                            22.3.1
# pkginfo                        1.8.3
# platformdirs                   2.5.2
# plotly                         5.9.0
# pluggy                         1.0.0
# ply                            3.11
# pooch                          1.4.0
# poyo                           0.5.0
# prometheus-client              0.14.1
# prompt-toolkit                 3.0.36
# Protego                        0.1.16
# proto-plus                     1.22.2
# protobuf                       3.19.6
# psutil                         5.9.0
# psycopg2-binary                2.9.6
# ptyprocess                     0.7.0
# pure-eval                      0.2.2
# py                             1.11.0
# pyasn1                         0.4.8
# pyasn1-modules                 0.2.8
# pycodestyle                    2.10.0
# pycosat                        0.6.4
# pycparser                      2.21
# pyct                           0.5.0
# pycurl                         7.45.1
# pydantic                       1.10.8
# PyDispatcher                   2.0.5
# pydocstyle                     6.3.0
# pyerfa                         2.0.0
# pyflakes                       3.0.1
# Pygments                       2.11.2
# PyHamcrest                     2.0.2
# PyJWT                          2.4.0
# pylint                         2.16.2
# pylint-venv                    2.3.0
# pyls-spyder                    0.4.0
# PyNaCl                         1.5.0
# pyodbc                         4.0.34
# pyOpenSSL                      23.0.0
# pyparsing                      3.0.9
# PyQt5                          5.15.7
# PyQt5-sip                      12.11.0
# PyQtWebEngine                  5.15.4
# pyRFC3339                      1.1
# pyrsistent                     0.18.0
# PySocks                        1.7.1
# pytest                         7.1.2
# python-dateutil                2.8.2
# python-json-logger             2.0.4
# python-lsp-black               1.2.1
# python-lsp-jsonrpc             1.0.0
# python-lsp-server              1.7.1
# python-slugify                 5.0.2
# python-snappy                  0.6.1
# pytoolconfig                   1.2.5
# pytz                           2019.3
# pyviz-comms                    2.0.2
# PyWavelets                     1.4.1
# pywin32                        305.1
# pywin32-ctypes                 0.2.0
# pywinpty                       2.0.10
# PyYAML                         6.0
# pyzmq                          23.2.0
# QDarkStyle                     3.0.2
# qstylizer                      0.2.2
# QtAwesome                      1.2.2
# qtconsole                      5.4.0
# QtPy                           2.2.0
# queuelib                       1.5.0
# redis                          4.5.5
# regex                          2022.7.9
# requests                       2.28.0
# requests-file                  1.5.1
# requests-oauthlib              1.3.0
# rope                           1.7.0
# rq                             1.10.1
# rsa                            4.7.2
# Rtree                          1.0.1
# ruamel.yaml                    0.17.21
# ruamel.yaml.clib               0.2.6
# ruamel-yaml-conda              0.17.21
# rules                          2.2
# s3transfer                     0.3.7
# scikit-image                   0.19.3
# scikit-learn                   1.2.1
# scikit-learn-intelex           20230228.214818
# scipy                          1.10.0
# Scrapy                         2.8.0
# seaborn                        0.12.2
# selenium                       4.9.1
# semver                         2.13.0
# Send2Trash                     1.8.0
# sentry-sdk                     1.25.0
# service-identity               18.1.0
# setuptools                     65.6.3
# simplejson                     3.19.1
# sip                            6.6.2
# six                            1.16.0
# smart-open                     5.2.1
# sniffio                        1.2.0
# snowballstemmer                2.2.0
# sortedcontainers               2.4.0
# soupsieve                      2.3.2.post1
# Sphinx                         5.0.2
# sphinxcontrib-applehelp        1.0.2
# sphinxcontrib-devhelp          1.0.2
# sphinxcontrib-htmlhelp         2.0.0
# sphinxcontrib-jsmath           1.0.1
# sphinxcontrib-qthelp           1.0.3
# sphinxcontrib-serializinghtml  1.1.5
# spyder                         5.4.1
# spyder-kernels                 2.4.1
# SQLAlchemy                     1.4.39
# sqlparse                       0.4.4
# stack-data                     0.2.0
# statsmodels                    0.13.5
# sweetviz                       2.1.4
# sympy                          1.11.1
# tables                         3.7.0
# tabulate                       0.8.10
# TBB                            0.2
# tblib                          1.7.0
# tenacity                       8.0.1
# tensorboard                    2.10.0
# tensorboard-data-server        0.6.1
# tensorboard-plugin-wit         1.8.1
# tensorflow                     2.10.0
# tensorflow-estimator           2.10.0
# tensorflow-io-gcs-filesystem   0.31.0
# termcolor                      2.1.0
# terminado                      0.17.1
# text-unidecode                 1.3
# textdistance                   4.2.1
# threadpoolctl                  2.2.0
# three-merge                    0.1.1
# tifffile                       2021.7.2
# tinycss2                       1.2.1
# tldextract                     3.2.0
# tokenizers                     0.11.4
# toml                           0.10.2
# tomli                          2.0.1
# tomlkit                        0.11.1
# toolz                          0.12.0
# torch                          1.12.1
# tornado                        6.1
# tqdm                           4.64.1
# traitlets                      5.7.1
# transformers                   4.24.0
# trio                           0.22.0
# trio-websocket                 0.10.2
# Twisted                        22.2.0
# twisted-iocpsupport            1.0.2
# typing_extensions              4.4.0
# ua-parser                      0.16.1
# ujson                          5.4.0
# Unidecode                      1.2.0
# uritemplate                    4.1.1
# urllib3                        1.26.14
# user-agents                    2.2.0
# w3lib                          1.21.0
# watchdog                       2.1.6
# wcwidth                        0.2.5
# webencodings                   0.5.1
# websocket-client               0.58.0
# Werkzeug                       2.2.2
# whatthepatch                   1.0.2
# wheel                          0.38.4
# widgetsnbextension             3.5.2
# win-inet-pton                  1.1.0
# wincertstore                   0.2
# wrapt                          1.14.1
# wsproto                        1.2.0
# xarray                         2022.11.0
# xlwings                        0.29.1
# xmljson                        0.2.0
# yapf                           0.31.0
# yarl                           1.8.1
# zict                           2.1.0
# zipp                           3.11.0
# zope.interface                 5.4.0
# zstandard                      0.19.0

# %%
# !pip install object-detection
# Out:
# Collecting object-detection
#   Downloading object_detection-0.0.3-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from object-detection) (9.3.0)
# Collecting Cython
#   Using cached Cython-0.29.35-py2.py3-none-any.whl (988 kB)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from object-detection) (3.7.0)
# Requirement already satisfied: tensorflow in c:\users\hp\anaconda3\lib\site-packages (from object-detection) (2.10.0)
# Requirement already satisfied: jupyter in c:\users\hp\anaconda3\lib\site-packages (from object-detection) (1.0.0)
# Collecting contextlib2
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: lxml in c:\users\hp\anaconda3\lib\site-packages (from object-detection) (4.9.1)
# Requirement already satisfied: ipykernel in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object-detection) (6.19.2)
# Requirement already satisfied: ipywidgets in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object-detection) (7.6.5)
# Requirement already satisfied: jupyter-console in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object-detection) (6.6.2)
# Requirement already satisfied: nbconvert in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object-detection) (6.5.4)
# Requirement already satisfied: notebook in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object-detection) (6.5.2)
# Requirement already satisfied: qtconsole in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object-detection) (5.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (4.25.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (1.21.6)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object-detection) (2.8.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (1.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (2.10.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (1.48.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (4.4.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (2.10.0)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (65.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (2.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp310-cp310-win_amd64.whl (895 kB)
#      ------------------------------------- 895.7/895.7 kB 27.7 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object-detection) (0.4.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow->object-detection) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object-detection) (2.11.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object-detection) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object-detection) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object-detection) (2.28.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object-detection) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object-detection) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object-detection) (0.6.1)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (5.9.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (7.3.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (8.10.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object-detection) (1.5.6)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object-detection) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object-detection) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object-detection) (5.7.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object-detection) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->object-detection) (3.0.36)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->object-detection) (5.2.0)
# Requirement already satisfied: pygments in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->object-detection) (2.11.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (0.8.4)
# Requirement already satisfied: tinycss2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (1.2.1)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (1.5.0)
# Requirement already satisfied: jinja2>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (0.4)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object-detection) (0.7.1)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object-detection) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object-detection) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object-detection) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object-detection) (0.5.2)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object-detection) (0.14.1)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\hp\anaconda3\lib\site-packages (from qtconsole->jupyter->object-detection) (2.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object-detection) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object-detection) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object-detection) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow->object-detection) (1.3.0)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.2.0)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.4.6)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (5.1.1)
# Collecting python-dateutil>=2.7
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->object-detection) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->object-detection) (2.5.2)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->object-detection) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->object-detection) (1.23.4)
# Requirement already satisfied: fastjsonschema in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->object-detection) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->object-detection) (3.2.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->object-detection) (0.2.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object-detection) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object-detection) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object-detection) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object-detection) (3.4)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->object-detection) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->object-detection) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->object-detection) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->object-detection) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.8.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->object-detection) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->object-detection) (22.1.0)
# Requirement already satisfied: websocket-client in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->object-detection) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->object-detection) (3.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object-detection) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow->object-detection) (3.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->object-detection) (1.15.1)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object-detection) (2.0.5)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->object-detection) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->object-detection) (2.21)
# Installing collected packages: libclang, tensorflow-io-gcs-filesystem, python-dateutil, protobuf, Cython, contextlib2, object-detection
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed Cython-0.29.35 contextlib2-21.6.0 libclang-16.0.0 object-detection-0.0.3 protobuf-3.19.6 python-dateutil-2.8.2 tensorflow-io-gcs-filesystem-0.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# label-studio 1.7.3 requires python-dateutil==2.8.1, but you have python-dateutil 2.8.2 which is incompatible.
# google-api-core 2.10.0 requires protobuf<5.0.0dev,>=3.20.1, but you have protobuf 3.19.6 which is incompatible.
# conda-repo-cli 1.0.27 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.27 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.27 requires requests==2.28.1, but you have requests 2.28.0 which is incompatible.
# anaconda-client 1.11.1 requires pytz>=2021.3, but you have pytz 2019.3 which is incompatible.

# %%
import os
import pathlib

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from six import BytesIO
from PIL import Image
from tqdm import tqdm
import tensorflow as tf
import cv2

# %% [markdown]
# ## Utilities
#
# Run the following cell to create some utils that will be needed later:
#
# - Helper method to load an image

# %%
def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
    path: the file path to the image

    Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
    """
    image = None
    if(path.startswith('http')):
        response = urlopen(path)
        image_data = response.read()
        image_data = BytesIO(image_data)
        image = Image.open(image_data)
    else:
        image_data = tf.io.gfile.GFile(path, 'rb').read()
        image = Image.open(BytesIO(image_data))

        (im_width, im_height) = image.size
        
    return np.array(image.getdata())[:,:3].reshape(
      (1, im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# ## Visualization tools
#
# To visualize the images with the proper detected boxes, we will use the TensorFlow Object Detection API.

# %%
# !pip install --upgrade object_detection
# Out:
# Requirement already satisfied: object_detection in c:\users\hp\anaconda3\lib\site-packages (0.0.3)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from object_detection) (3.7.0)
# Requirement already satisfied: Cython in c:\users\hp\anaconda3\lib\site-packages (from object_detection) (0.29.35)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from object_detection) (9.3.0)
# Requirement already satisfied: jupyter in c:\users\hp\anaconda3\lib\site-packages (from object_detection) (1.0.0)
# Requirement already satisfied: contextlib2 in c:\users\hp\anaconda3\lib\site-packages (from object_detection) (21.6.0)
# Requirement already satisfied: tensorflow in c:\users\hp\anaconda3\lib\site-packages (from object_detection) (2.10.0)
# Requirement already satisfied: lxml in c:\users\hp\anaconda3\lib\site-packages (from object_detection) (4.9.1)
# Requirement already satisfied: qtconsole in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object_detection) (5.4.0)
# Requirement already satisfied: notebook in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object_detection) (6.5.2)
# Requirement already satisfied: nbconvert in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object_detection) (6.5.4)
# Requirement already satisfied: jupyter-console in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object_detection) (6.6.2)
# Requirement already satisfied: ipykernel in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object_detection) (6.19.2)
# Requirement already satisfied: ipywidgets in c:\users\hp\anaconda3\lib\site-packages (from jupyter->object_detection) (7.6.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (1.21.6)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->object_detection) (22.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (4.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (65.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (1.48.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (0.31.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (2.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (1.16.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (1.1.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (2.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (16.0.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (1.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow->object_detection) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow->object_detection) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object_detection) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object_detection) (2.11.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object_detection) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object_detection) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object_detection) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object_detection) (2.28.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow->object_detection) (0.6.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (8.10.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (6.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (1.5.6)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (5.9.0)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (5.7.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter->object_detection) (23.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object_detection) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object_detection) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object_detection) (5.7.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets->jupyter->object_detection) (1.0.0)
# Requirement already satisfied: pygments in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->object_detection) (2.11.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->object_detection) (5.2.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-console->jupyter->object_detection) (3.0.36)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (0.7.1)
# Requirement already satisfied: tinycss2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (2.1.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (3.1.2)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->jupyter->object_detection) (5.0.1)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object_detection) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object_detection) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object_detection) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object_detection) (0.5.2)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\lib\site-packages (from notebook->jupyter->object_detection) (0.14.1)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\hp\anaconda3\lib\site-packages (from qtconsole->jupyter->object_detection) (2.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object_detection) (4.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object_detection) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object_detection) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow->object_detection) (1.3.0)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.7.5)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.18.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->object_detection) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->object_detection) (305.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->object_detection) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->object_detection) (1.23.4)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->object_detection) (3.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->object_detection) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->object_detection) (0.2.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object_detection) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object_detection) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object_detection) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow->object_detection) (2023.5.7)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->object_detection) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->object_detection) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->object_detection) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->object_detection) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->object_detection) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->object_detection) (0.18.0)
# Requirement already satisfied: websocket-client in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->object_detection) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->object_detection) (3.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow->object_detection) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow->object_detection) (3.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->object_detection) (1.15.1)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object_detection) (2.0.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->object_detection) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->object_detection) (2.21)

# %%
# !conda activate ataTry

# %%
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = "C:/Users/HP/Desktop/y3s1/aap/ataTry/project/balloon_project/exported_models/my_model"

print('Loading model...', end='')
start_time = time.time()

# Load saved model and build the detection function
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import time
# ----> 2 from object_detection.utils import label_map_util
#       3 from object_detection.utils import visualization_utils as viz_utils
#       5 PATH_TO_SAVED_MODEL = "C:/Users/HP/Desktop/y3s1/aap/ataTry/project/balloon_project/exported_models/my_model"
#
# File ~\anaconda3\envs\ataTry\lib\site-packages\object_detection\utils\label_map_util.py:21
#      19 import tensorflow as tf
#      20 from google.protobuf import text_format
# ---> 21 from object_detection.protos import string_int_label_map_pb2
#      24 def _validate_label_map(label_map):
#      25   """Checks if a label map is valid.
#      26
#      27   Args:
#    (...)
#      31     ValueError: if label map is invalid.
#      32   """
#
# ImportError: cannot import name 'string_int_label_map_pb2' from 'object_detection.protos' (C:\Users\HP\anaconda3\envs\ataTry\lib\site-packages\object_detection\protos\__init__.py)

# %%
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import ops as utils_ops

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from object_detection.utils import label_map_util
#       2 from object_detection.utils import visualization_utils as viz_utils
#       3 from object_detection.utils import ops as utils_ops
#
# File ~\anaconda3\lib\site-packages\object_detection\utils\label_map_util.py:21
#      19 import tensorflow as tf
#      20 from google.protobuf import text_format
# ---> 21 from object_detection.protos import string_int_label_map_pb2
#      24 def _validate_label_map(label_map):
#      25   """Checks if a label map is valid.
#      26
#      27   Args:
#    (...)
#      31     ValueError: if label map is invalid.
#      32   """
#
# ImportError: cannot import name 'string_int_label_map_pb2' from 'object_detection.protos' (C:\Users\HP\anaconda3\lib\site-packages\object_detection\protos\__init__.py)

# %% [markdown]
# ### Load label map data (for plotting).
#
# Label maps correspond index numbers to category name. For example, if our COCO-trained model predicts `5`, we know that this corresponds to `airplane`. Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine.
#
# We will load the label_map we created for our balloon detector, which only contains one class.

# %%
PATH_TO_LABELS = 'data/label_map.pbtxt'
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# %%
category_index

# %% [markdown]
# ## Loading our saved custom model
#
# Here we will load our trained balloon detection model and use it later to detect our picture and videos.

# %%
## Uncomment the following if you want to use a pretrained balloon detection model

# !wget https://nyp-aicourse.s3-ap-southeast-1.amazonaws.com/pretrained-models/balloon_model.tar.gz
# !mkdir mymodel
# !tar xzvf balloon_model.tar.gz -C mymodel

# %%
model = 'ssd_mobilenet_v2_320x320_coco17_tpu-8'
experiment='run1'
export_root_dir = '/home/ubuntu/balloon_project/exported_models'

# Uncomment the following if you want to use a pretrained balloon detection model
# model_dir = 'mymodel/saved_model'
model_dir = os.path.join(export_root_dir, f'{model}/{experiment}/saved_model')

# load the model
detection_model = tf.saved_model.load(str(model_dir))

# %% [markdown]
# ## Loading an image
#
# Let's try the model on your own image. You can upload your image using the code below. The code below uses ipywidgets [FileUpload](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html) widget to upload file

# %%
import ipywidgets as widgets

uploader = widgets.FileUpload(
    accept='image/*',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple=False  # True to accept multiple files upload else False
)

display(uploader)

# %% [markdown]
# After upload, we need to write the upload data to a file. The content of the upload data can be found in ``uploader.data[0]``.

# %%
key = next(iter(uploader.value))

samples_folder = 'test_samples'

if not os.path.exists(samples_folder):
    os.mkdir(samples_folder)

image_path = os.path.join(samples_folder, key)

with open(image_path, "w+b") as file:
    file.write(uploader.data[0])

# %%
image_np = load_image_into_numpy_array(image_path)
plt.figure(figsize=(24,32))
plt.imshow(image_np[0])
plt.show()

# %% [markdown]
# ## Doing the inference
#
# To do the inference we just need to call our detection model. The detection model expect the following input and output a dictionary of items described below:
#
# *Inputs*:
#
# A three-channel image of variable size - the model does NOT support batching. The input tensor is a tf.uint8 tensor with shape [1, height, width, 3] with values in [0, 255].
#
# *Outputs*:
#
# The output dictionary contains:
#
# - num_detections: a tf.int tensor with only one value, the number of detections [N].
#
# - detection_boxes: a tf.float32 tensor of shape [N, 4] containing bounding box coordinates in the following order: [ymin, xmin, ymax, xmax].
# - detection_classes: a tf.int tensor of shape [N] containing detection class index from the label file.
# - detection_scores: a tf.float32 tensor of shape [N] containing detection scores.
# - raw_detection_boxes: a tf.float32 tensor of shape [1, M, 4] containing decoded detection boxes without Non-Max suppression. M is the number of raw detections.
# - raw_detection_scores: a tf.float32 tensor of shape [1, M, 90] and contains class score logits for raw detection boxes. M is the number of raw detections.
# - detection_anchor_indices: a tf.float32 tensor of shape [N] and contains the anchor indices of the detections after NMS.
# - detection_multiclass_scores: a tf.float32 tensor of shape [1, N, 90] and contains class score distribution (including background) for detection boxes in the image including background class.

# %%
# running inference
results = detection_model(image_np)

# different object detection models have additional results
result = {key:value.numpy() for key,value in results.items()}
print(result.keys())

# %% [markdown]
# ## Visualizing the results
#
# Here is where we will need the TensorFlow Object Detection API to show the squares from the inference step (and the keypoints when available). The full documentation of this method can be seen [here](https://github.com/tensorflow/models/blob/master/research/object_detection/utils/visualization_utils.py)
#
# Here you can, for example, set `min_score_thresh` to other values (between 0 and 1) to allow more detections in or to filter out more detections.

# %%
label_id_offset = 0
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_detections[0],
      result['detection_boxes'][0],
      (result['detection_classes'][0] + label_id_offset).astype(int),
      result['detection_scores'][0],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=.60,
      agnostic_mode=False,
      line_thickness=2)

plt.figure(figsize=(24,32))
plt.imshow(image_np_with_detections[0])
plt.show()

# %% [markdown]
# ## Object Detection on Video
#
# We can also do object detection on a video file. We just treat our video file as a sequence of frames (images) and we run the detector on each frame. After we draw the bounding boxes on the frame (image), we then write the new image (with bounding boxes) to a video file, frame by frame.

# %%
def write_video(video_in_filepath, video_out_filepath, detection_model):
    if not os.path.exists(video_in_filepath):
        print('video filepath not valid')
    
    video_reader = cv2.VideoCapture(video_in_filepath)
    
    nb_frames = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_h = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_w = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    fps = video_reader.get(cv2.CAP_PROP_FPS)
    
    video_writer = cv2.VideoWriter(video_out_filepath,
                               cv2.VideoWriter_fourcc(*'mp4v'), 
                               fps, 
                               (frame_w, frame_h))

    for i in tqdm(range(nb_frames)):
        ret, image_np = video_reader.read()
        input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.uint8)
        results = detection_model(input_tensor)
        viz_utils.visualize_boxes_and_labels_on_image_array(
                  image_np,
                  results['detection_boxes'][0].numpy(),
                  (results['detection_classes'][0].numpy()+ label_id_offset).astype(int),
                  results['detection_scores'][0].numpy(),
                  category_index,
                  use_normalized_coordinates=True,
                  max_boxes_to_draw=200,
                  min_score_thresh=.50,
                  agnostic_mode=False,
                  line_thickness=2)

        video_writer.write(np.uint8(image_np))
                
    # Release camera and close windows
    video_reader.release()
    video_writer.release() 
    cv2.destroyAllWindows() 
    cv2.waitKey(1)

# %%
uploader = widgets.FileUpload(
    accept='.mp4',  # Accepted file extension only '.mp4'
    multiple=False  # True to accept multiple files upload else False
)

display(uploader)

# %%
key = next(iter(uploader.value))

samples_folder = 'test_samples'

if not os.path.exists(samples_folder):
    os.mkdir(samples_folder)
video_in_file = os.path.join(samples_folder, key)
with open(video_in_file, "w+b") as file:
    file.write(uploader.data[0])

# %%
from pathlib import Path

basename = Path(video_in_file).stem
video_out_file = os.path.join(samples_folder, basename + '_detected' + '.mp4')

write_video(video_in_file, video_out_file, detection_model)
